# %%
# %run Arm3Link.ipynb
# %run Arm_Plot.ipynb
# %run plot_tools.ipynb

# %matplotlib inline
# %run embed_animation.ipynb

# %%
import numpy as np
import networkx as nx
from scipy import spatial

from matplotlib import animation
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3

# %%
class RRT_Baseline():
    def __init__(self, robot, start, goal, tolerance, delta = 1/180.0):

        self.tree1 = nx.DiGraph()

        self.n_iters = 0
        self.n_extensions = 0

        self.robot = robot
        self.start = start
        self.goal  = goal
        self.tolerance  = tolerance
        self.goal_found  = False
        self.delta = delta
        
        self.next_node_id = 0
        self.start_node_id = self.next_node_id
        self.tree1.add_node(self.start_node_id, attr_dict={'state':self.start})
        
    def get_node_id(self):
        _id = self.next_node_id
        self.next_node_id += 1
        return _id
    
    def nearest_neighbor(self, tree, state):
        node_so_far = None
        distance_so_far = None
        for this_node in tree.nodes_iter():
            this_distance = self.distance(tree.node[this_node]['state'],state) 
            if(distance_so_far is None):
                distance_so_far = this_distance
                node_so_far = this_node
            elif(distance_so_far > this_distance):
                node_so_far = this_node
                distance_so_far = this_distance
        return (node_so_far,distance_so_far)
    
    def search(self,iters=500):
        iters = int(iters)
        for i in xrange(iters):
            self.n_iters += 1
            q_rand = self.sample()
            self.extend(q_rand)
            if self.goal_found:
                return True
        return False
    
    def extend(self,q_rand):
        self.n_extensions += 1
        tree = self.tree1

        q_nearest_id, nearest_distance  = self.nearest_neighbor(tree, q_rand)
        x_new_id = self.extend_from(tree, q_nearest_id, q_rand)
    
    def extend_from(self, tree, q_nearest_id, q_rand):

        q_new, action = self.steer(tree, q_nearest_id, q_rand)
        
        collision_free = self.collision_free(q_new)        
        if collision_free:
            q_new_id = self.get_node_id()
            tree.add_node(q_new_id,attr_dict={'state': q_new})
            tree.add_edge(q_nearest_id,q_new_id)
            self.check_goal(tree, q_new_id)
            return q_new_id
        
        return None

    def steer(self, tree, q_nearest_id, q_rand):       
        q_near = tree.node[q_nearest_id]['state']
        direction = q_rand - q_near
        unit_direction = direction / np.linalg.norm(direction)
        action = unit_direction * self.delta
        q_new = q_near + action
        return q_new, action
        
    def best_solution_(self, tree, state):

        path = []        
        parent = self.nearest_neighbor(tree, state)[0]
        path.append(parent)
        
        while(parent != self.start_node_id): #until you get at the root
            parent = tree.predecessors(parent)                
            assert len(parent)==1
            parent = parent[0]
            path.append(parent)            
        return path[::-1] #reverse
        
    def best_solution(self, tree, state):
        goal_id = self.nearest_neighbor(tree, state)[0]
        graph = tree.reverse()
        path = nx.shortest_path(graph, source=goal_id, target=self.start_node_id)
        return path[::-1]
    
    
    def check_goal(self, tree, node_id):
        distance = self.distance(self.goal, tree.node[node_id]['state'])
        self.goal_found = distance <= self.tolerance
        
    def collision_free(self,q):
        """
        collision_check(state) = True/False
        """
        return self.robot.collision_free(q)
    
    def sample(self):
        """
        sample() returns point in state space
        """
        return np.random.uniform(-np.pi, np.pi, size=3)
    
    def distance(self,u,v):
        """
        distance(from_node,to_point)
        """
        return spatial.distance.euclidean(u, v)

# %%
start = np.array([0.14,1.45,1.0])
goal  = np.array([-2.5,-0.5,-2.1])
print goal
tolerance = np.pi/180.0 *50
delta = np.pi/180.0 *10
robot = Robot(scene2)

rrt_baseline = RRT_Baseline(robot, start, goal, tolerance, delta)

rrt_baseline.search(5000)
# Out:
# [-2.5 -0.5 -2.1]
# True

# %%
rrt_baseline.tree1.nodes(data=True)[-10:]
# Out:
# [(972, {'state': array([-0.8011119 , -2.04159496, -2.59318391])}),
#  (973, {'state': array([-0.64883035, -2.6049862 ,  0.0632378 ])}),
#  (974, {'state': array([ 0.67588669,  1.00805464, -2.35680186])}),
#  (975, {'state': array([-1.92598477,  0.64388884, -0.97785676])}),
#  (976, {'state': array([ 1.44439946,  1.1255782 , -1.26191341])}),
#  (977, {'state': array([ 1.83420896, -0.8443729 ,  0.85243778])}),
#  (978, {'state': array([-0.82261916,  1.4085628 ,  2.28498793])}),
#  (979, {'state': array([-2.62645262, -0.48211608,  0.94528752])}),
#  (980, {'state': array([-2.74054154,  0.44084854, -2.10947134])}),
#  (981, {'state': array([-2.72443082,  0.27073917, -2.14503802])})]

# %%
fig = drawTree(rrt=rrt_baseline, title='RRT Baseline')
plt.show()

# %%
anim = animateTree(rrt=rrt_baseline, title='RRT Baseline')
anim
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d2531205ec00> in <module>()
#       1 anim = animateTree(rrt=rrt_baseline, title='RRT Baseline')
# ----> 2 anim
#       3 # plt.show()
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     250             self.start_displayhook()
#     251             self.write_output_prompt()
# --> 252             format_dict, md_dict = self.compute_format_data(result)
#     253             self.write_format_data(format_dict, md_dict)
#     254             self.update_user_ns(result)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     152
#     153         """
# --> 154         return self.shell.display_formatter.format(result)
#     155
#     156     def write_format_data(self, format_dict, md_dict=None):
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     198             md = None
#     199             try:
# --> 200                 data = formatter(obj)
#     201             except:
#     202                 # FIXME: log the exception
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in warn_format_error(method, self, *args, **kwargs)
#     231     """decorator for warning on failed format call"""
#     232     try:
# --> 233         r = method(self, *args, **kwargs)
#     234     except NotImplementedError as e:
#     235         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     352             method = _safe_get_formatter_method(obj, self.print_method)
#     353             if method is not None:
# --> 354                 return method()
#     355             return None
#     356         else:
#
# <ipython-input-1-020b48da7e62> in anim_to_html(anim)
#       8     if not hasattr(anim, '_encoded_video'):
#       9         with NamedTemporaryFile(suffix='.mp4') as f:
# ---> 10             anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
#      11             video = open(f.name, "rb").read()
#      12         anim._encoded_video = video.encode("base64")
#
# /usr/lib/pymodules/python2.7/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     716                     #TODO: Need to see if turning off blit is really necessary
#     717                     anim._draw_next_frame(d, blit=False)
# --> 718                 writer.grab_frame(**savefig_kwargs)
#     719
#     720         # Reconnect signal for first draw if necessary
#
# /usr/lib/pymodules/python2.7/matplotlib/animation.pyc in grab_frame(self, **savefig_kwargs)
#     202             # frame format and dpi.
#     203             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 204                              dpi=self.dpi, **savefig_kwargs)
#     205         except RuntimeError:
#     206             out, err = self._proc.communicate()
#
# /usr/lib/pymodules/python2.7/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1419             self.set_frameon(frameon)
#    1420
# -> 1421         self.canvas.print_figure(*args, **kwargs)
#    1422
#    1423         if frameon:
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2223                 restore_bbox()
#    2224
# -> 2225             self.figure.dpi = origDPI
#    2226             self.figure.set_facecolor(origfacecolor)
#    2227             self.figure.set_edgecolor(origedgecolor)
#
# /usr/lib/pymodules/python2.7/matplotlib/figure.pyc in _set_dpi(self, dpi)
#     382     def _set_dpi(self, dpi):
#     383         self._dpi = dpi
# --> 384         self.dpi_scale_trans.clear().scale(dpi, dpi)
#     385         self.callbacks.process('dpi_changed', self)
#     386     dpi = property(_get_dpi, _set_dpi)
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in clear(self)
#    1785         """
#    1786         self._mtx = np.identity(3)
# -> 1787         self.invalidate()
#    1788         return self
#    1789
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in invalidate(self)
#     129         if self.is_affine:
#     130             value = self.INVALID_AFFINE
# --> 131         return self._invalidate_internal(value, invalidating_node=self)
#     132
#     133     def _invalidate_internal(self, value, invalidating_node):
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     153             for parent in self._parents.values():
#     154                 parent._invalidate_internal(value=value,
# --> 155                                             invalidating_node=self)
#     156
#     157     def set_children(self, *children):
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     153             for parent in self._parents.values():
#     154                 parent._invalidate_internal(value=value,
# --> 155                                             invalidating_node=self)
#     156
#     157     def set_children(self, *children):
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     153             for parent in self._parents.values():
#     154                 parent._invalidate_internal(value=value,
# --> 155                                             invalidating_node=self)
#     156
#     157     def set_children(self, *children):
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     153             for parent in self._parents.values():
#     154                 parent._invalidate_internal(value=value,
# --> 155                                             invalidating_node=self)
#     156
#     157     def set_children(self, *children):
#
# /usr/lib/pymodules/python2.7/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     152
#     153             for parent in self._parents.values():
# --> 154                 parent._invalidate_internal(value=value,
#     155                                             invalidating_node=self)
#     156
#
# KeyboardInterrupt:

# %%
# rrt_baseline.best_solution_(rrt_baseline.tree1, rrt_baseline.goal)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d',aspect='equal')

for node_id in rrt_baseline.tree1.nodes_iter():
    state = rrt_baseline.tree1.node[node_id]['state']
    ax.scatter(state[0], state[1], state[2])

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
path_nodes = rrt_baseline.best_solution(rrt_baseline.tree1, goal)

# %%
path = []
for step in path_nodes:
    path.append(rrt_baseline.tree1.node[step]['state'])
path.append(goal)

# %%
class UpdateArm(object):
    def __init__(self, ax, rrt, path):
        
        self.ax  = ax
        self.rrt = rrt
        self.rrt.robot.ax = ax
        self.path = path
    
    def draw(self,i):
        state = self.path[i]
        self.rrt.robot.draw_robot(state)
    
    def __call__(self, i):
        return self.draw(i)

def animateArm(rrt, title, path):
    my_dpi = 80
    fig = plt.figure(figsize=(1080/my_dpi, 720/my_dpi), dpi=my_dpi)
    ax = plt.axes(aspect='equal')
    
    ax.set_title(title)

    ud = UpdateArm(ax=ax, rrt=rrt, path=path)
    anim = animation.FuncAnimation(fig, ud, frames=len(ud.path), interval=1, blit=False)
    return anim

# %%
anim_arm = animateArm(rrt_baseline, 'Test', path)
anim_arm
# plt.show()
# Out:
# <video controls>
#  <source src="...
